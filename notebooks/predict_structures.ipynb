# %% [markdown]
#  <font size="6">Classification of typical structures using CNN pre-trained model</font>

# %% [markdown]
# # Setup and Preparation for Classification

# %% [markdown]
# Clone repository

# %%
# !git clone https://github.com/dmitkovskiy/Amphiphilic_Homopolymers_on_Nanoparticles_Classification.git
# Out:
# Cloning into 'Amphiphilic_Homopolymers_on_Nanoparticles_Classification'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 43 (delta 5), reused 42 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (43/43), 32.00 MiB | 22.16 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %% [markdown]
# Installation of required libraries

# %%
# %cd Amphiphilic_Homopolymers_on_Nanoparticles_Classification
# %pip install -q -r requirements.txt
# Out:
# /content/Amphiphilic_Homopolymers_on_Nanoparticles_Classification
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 960.9/960.9 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 818.9/818.9 kB 29.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 52.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 50.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# Importing libraries and modules

# %%
import numpy as np
import os
import sys

# %cd scripts
import prepare_data_functions as pdf
import my_models_functions as mmf
# %cd ../
# Out:
# /content/Amphiphilic_Homopolymers_on_Nanoparticles_Classification/scripts
# /content/Amphiphilic_Homopolymers_on_Nanoparticles_Classification

# %% [markdown]
# Load model

# %%
model_phi_theta_path = f"weights/model_phi_theta.ckpt"
model_phi_theta = mmf.load_my_image_pred_model(model_phi_theta_path)

# %% [markdown]
# ## Predict Catenoid

# %% [markdown]
# Load structure point cloud

# %%
structures_path = "data/structures/"
structure_name= "catenoid_example.npy"
structure = np.load(os.path.join(structures_path,structure_name))

# %% [markdown]
# Clustering of the structure, predictions of class labels for separate elements, mapping them with a possible structure

# %%
mmf.demo_predict_pipeline(structure, model_phi_theta)

# %% [markdown]
# ## Predict Costa

# %% [markdown]
# Load structure point cloud

# %%
structure_name= "costa_example.npy"
structure = np.load(os.path.join(structures_path,structure_name))

# %% [markdown]
# Clustering of the structure, predictions of class labels for separate elements, mapping them with a possible structure

# %%
mmf.demo_predict_pipeline(structure, model_phi_theta)

# %% [markdown]
# ## Predict Helicoid

# %% [markdown]
# Load structure point cloud

# %%
structure_name = "helicoid_example.npy"
structure = np.load(os.path.join(structures_path,structure_name))

# %% [markdown]
# Clustering of the structure, predictions of class labels for separate elements, mapping them with a possible structure

# %%
mmf.demo_predict_pipeline(structure, model_phi_theta)

# %% [markdown]
# ## Predict Double helicoid

# %% [markdown]
# Load structure point cloud

# %%
structure_name = "double helicoid_example.npy"
structure = np.load(os.path.join(structures_path,structure_name))

# %% [markdown]
# Clustering of the structure, predictions of class labels for separate elements, mapping them with a possible structure

# %%
mmf.demo_predict_pipeline(structure, model_phi_theta)

# %% [markdown]
# ## Predict Enneper

# %% [markdown]
# Load structure point cloud

# %%
structure_name = "enneper_example.npy"
structure = np.load(os.path.join(structures_path,structure_name))

# %% [markdown]
# Clustering of the structure, predictions of class labels for separate elements, mapping them with a possible structure

# %%
mmf.demo_predict_pipeline(structure, model_phi_theta)

# %% [markdown]
# ## Predict Complex structure

# %% [markdown]
# Load structure point cloud

# %%
structure_name = "complex structure_example.npy"
structure = np.load(os.path.join(structures_path,structure_name))

# %% [markdown]
# Clustering of the structure, predictions of class labels for separate elements, mapping them with a possible structure

# %%
mmf.demo_predict_pipeline(structure, model_phi_theta)
